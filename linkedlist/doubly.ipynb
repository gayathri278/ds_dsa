# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
n1=Node("240")
n2=Node("321")
n3=Node("140")

# %%
n1.prev=None
n1.next=n2
n2.prev=n1
n2.next=n3
n3.prev=n2
n3.next=None
cur=n1
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 240
# 321
# 140

# %%
print(n2.next.data)
# Out:
# 140

# %%
#node at the beginning, end, specific location
n0=Node("80")
n0.prev=None
n0.next=n1
n1.prev=n0
n4=Node("400")
n3.next=n4
n4.prev=n3
n4.next=None
cur=n0
while cur:
    print(cur.data)
    cur=cur.next
# Out:
# 80
# 240
# 321
# 140
# 400

# %%
cur=n0
while cur:
    if cur.data

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        self.prev=None
    n=int(input("Enter no.nodes:"))
    node=[]
    for i in range(1,n+1):
        if i==1:
            node[i].prev=None
            node[i].next=node[i+1]
            node[i].data=input("Enter data: ")
        elif i<n:
            node[i].prev=node[i-1]
            node[i].next=node[i+1]
            node[i].data=input("Enter data: ")
        else:
            node[i].prev=node[i-1]
            node[i].next=None
            node[i].data=input("Enter data: ")
# Out:
# Enter no.nodes: 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 class Node:
#       2     def __init__(self,data):
#       3         self.data=data
#       4         self.next=None
#
# Cell In[33], line 10, in Node()
#       6     n=int(input("Enter no.nodes:"))
#       7     node=[]
#       8     for i in range(1,n+1):
#       9         if i==1:
# ---> 10             node[i].prev=None
#      11             node[i].next=node[i+1]
#      12             node[i].data=input("Enter data: ")
#      13         elif i<n:
#
# IndexError: list index out of range

# %%
numbers=[]
n=int(input("Enter size of the list: "))
for i in range(n):
    digit=int(input("Enter a number: "))
    numbers.append(digit)
# Out:
# Enter size of the list:  5
# Enter a number:  1
# Enter a number:  2
# Enter a number:  4
# Enter a number:  5
# Enter a number:  6

# %%
numbers
# Out:
# [1, 2, 4, 5, 6]

# %%
formula=(n*(n+1))//2
print(formula)
sum=0
for i in range (n):
    sum+=numbers[i]
print(sum)
# Out:
# 15
# 18

# %%
difference=sum-formula
print("The missing number is: ",difference)
# Out:
# The missing number is:  3

# %%
count=0
for i in range (difference+1):
    count=count+1
    if count==difference:
         numbers[i]=difference
        while (i+1)!=
numbers
# Out:
# [1, 2, 3, 5, 6]
